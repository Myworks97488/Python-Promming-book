# %%
#stack programming


def is Empty(stk):
    if stk==[]:
        return True
    else:
        return False
        def Push(stk,item):
            stk.append(item)
            top=len(stk)-1
            def(stk):
            if is Empty(stk):
                return"unter flow"
            else:
                item=stk.pop()
                iflen(stk)==0:
                top=Non
            else:
            top=len(stk)-1
            return item

def peek(stk):
    if is empty(stk):
        return"underflow"
    else:
        top=len(stk)-1
        return stk[top]
        def Display(stk:
                    if sEmpty(stk):
            print("stack empty")
    else:
    top=len(stk)-1
    print(stk[top],"<-top")
    for a in range(top-1,-1,-1):
        print(stk[a])

#_main_
sack=[]
top=None
while True:
    print("STACK OPEATIONS")
    print("1.Push")
    print("2.Pop")
    print("3.peek")
    print("4.Display stack")
    print("5.Exit")
    ch=int(input("enter your choice(1-5):"))
    if ch==1:
        item=int(input("enter item:"))
            push(Stack,item)
    elif ch==2:
        item=pop(stack)
        if item=="underflow":
            print("underflow!stack is empty!")
        else:
            print("Topmost item is",item)
        elif ch==5:
        break
else:
    print("Incalid choice!")
